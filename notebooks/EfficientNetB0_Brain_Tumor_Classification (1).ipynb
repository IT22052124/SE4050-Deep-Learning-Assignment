# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/IT22052124/SE4050-Deep-Learning-Assignment
# Out:
# Cloning into 'SE4050-Deep-Learning-Assignment'...
# remote: Enumerating objects: 3513, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 3513 (delta 68), reused 92 (delta 43), pack-reused 3393 (from 2)
# Receiving objects: 100% (3513/3513), 63.27 MiB | 25.55 MiB/s, done.
# Resolving deltas: 100% (239/239), done.

# %%
# %cd SE4050-Deep-Learning-Assignment
# Out:
# /content/SE4050-Deep-Learning-Assignment

# %%
# !pip install tensorflow keras matplotlib scikit-learn opencv-python kagglehub
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras) (0.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)

# %%
import kagglehub

path = kagglehub.dataset_download("ahmedhamada0/brain-tumor-detection")
print("✅ Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'brain-tumor-detection' dataset.
# ✅ Path to dataset files: /kaggle/input/brain-tumor-detection

# %%
import os, shutil

DATASET_SRC = path + "/Brain Tumor Classification Data Set"
DATASET_DIR = "/kaggle/input/brain-tumor-detection"
if not os.path.exists(DATASET_DIR):
    shutil.copytree(DATASET_SRC, DATASET_DIR)
print("✅ Dataset ready at:", DATASET_DIR)
# Out:
# ✅ Dataset ready at: /kaggle/input/brain-tumor-detection

# %%
import os
import random
from shutil import copy2
from sklearn.model_selection import train_test_split

SRC_DIR = DATASET_DIR
DEST_DIR = "/content/Brain_Tumor_Dataset_Split"
os.makedirs(DEST_DIR, exist_ok=True)

classes = ['yes', 'no']
splits = ['train', 'val', 'test']
ratios = [0.7, 0.15, 0.15]  # 70/15/15 split

for split in splits:
    for cls in classes:
        os.makedirs(os.path.join(DEST_DIR, split, cls), exist_ok=True)

for cls in classes:
    files = os.listdir(os.path.join(SRC_DIR, cls))
    random.shuffle(files)

    train_files, temp = train_test_split(files, test_size=(1-ratios[0]), random_state=42)
    val_files, test_files = train_test_split(temp, test_size=0.5, random_state=42)

    for f in train_files:
        copy2(os.path.join(SRC_DIR, cls, f), os.path.join(DEST_DIR, 'train', cls))
    for f in val_files:
        copy2(os.path.join(SRC_DIR, cls, f), os.path.join(DEST_DIR, 'val', cls))
    for f in test_files:
        copy2(os.path.join(SRC_DIR, cls, f), os.path.join(DEST_DIR, 'test', cls))

print("✅ Dataset split complete")
# Out:
# ✅ Dataset split complete

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    zoom_range=0.2,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    os.path.join(DEST_DIR, 'train'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'
)
val_gen = val_test_datagen.flow_from_directory(
    os.path.join(DEST_DIR, 'val'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'
)
test_gen = val_test_datagen.flow_from_directory(
    os.path.join(DEST_DIR, 'test'),
    target_size=IMG_SIZE,
    batch_size=1,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 2098 images belonging to 2 classes.
# Found 450 images belonging to 2 classes.
# Found 452 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers, models, optimizers

def build_efficientnetb0(input_shape=(224,224,3)):
    base_model = EfficientNetB0(include_top=False, weights="imagenet", input_shape=input_shape)
    base_model.trainable = False

    inputs = layers.Input(shape=input_shape)
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs, outputs)
    model.compile(optimizer=optimizers.Adam(1e-4), loss='binary_crossentropy', metrics=['accuracy'])
    return model

model = build_efficientnetb0()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         1,281 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,050,852 (15.45 MB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

RESULTS_DIR = "/content/efficientnetb0_results"
os.makedirs(RESULTS_DIR, exist_ok=True)

checkpoint = ModelCheckpoint(os.path.join(RESULTS_DIR, "best_model.keras"),
                             monitor='val_accuracy', save_best_only=True, mode='max')
earlystop = EarlyStopping(monitor='val_accuracy', patience=7, restore_best_weights=True)

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=30,
    callbacks=[checkpoint, earlystop]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.5180 - loss: 0.6991 - val_accuracy: 0.4711 - val_loss: 0.6944
# Epoch 2/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 438ms/step - accuracy: 0.5978 - loss: 0.6547 - val_accuracy: 0.4956 - val_loss: 0.6959
# Epoch 3/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 430ms/step - accuracy: 0.6457 - loss: 0.6253 - val_accuracy: 0.5489 - val_loss: 0.6914
# Epoch 4/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 416ms/step - accuracy: 0.6338 - loss: 0.6283 - val_accuracy: 0.5000 - val_loss: 0.6933
# Epoch 5/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 426ms/step - accuracy: 0.6507 - loss: 0.6276 - val_accuracy: 0.5089 - val_loss: 0.6870
# Epoch 6/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 446ms/step - accuracy: 0.6438 - loss: 0.6143 - val_accuracy: 0.6200 - val_loss: 0.6644
# Epoch 7/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 424ms/step - accuracy: 0.6471 - loss: 0.6037 - val_accuracy: 0.7333 - val_loss: 0.6326
# Epoch 8/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 414ms/step - accuracy: 0.6341 - loss: 0.6293 - val_accuracy: 0.7000 - val_loss: 0.6132
# Epoch 9/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 426ms/step - accuracy: 0.6588 - loss: 0.5960 - val_accuracy: 0.7467 - val_loss: 0.5811
# Epoch 10/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 415ms/step - accuracy: 0.6622 - loss: 0.5988 - val_accuracy: 0.7356 - val_loss: 0.5768
# Epoch 11/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 420ms/step - accuracy: 0.6493 - loss: 0.6026 - val_accuracy: 0.7311 - val_loss: 0.5735
# Epoch 12/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 426ms/step - accuracy: 0.6878 - loss: 0.5719 - val_accuracy: 0.7244 - val_loss: 0.5551
# Epoch 13/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 439ms/step - accuracy: 0.6666 - loss: 0.5878 - val_accuracy: 0.7333 - val_loss: 0.5634
# Epoch 14/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 428ms/step - accuracy: 0.6827 - loss: 0.5883 - val_accuracy: 0.7311 - val_loss: 0.5624
# Epoch 15/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 451ms/step - accuracy: 0.6469 - loss: 0.6101 - val_accuracy: 0.7133 - val_loss: 0.5601
# Epoch 16/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 427ms/step - accuracy: 0.6818 - loss: 0.5779 - val_accuracy: 0.7089 - val_loss: 0.5680

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.legend(); plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(); plt.title('Loss')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import numpy as np

model.load_weights(os.path.join(RESULTS_DIR, "best_model.keras"))

test_gen.reset()
preds = model.predict(test_gen, verbose=1)
y_pred = (preds > 0.5).astype(int).flatten()
y_true = test_gen.classes

print("✅ Accuracy:", np.mean(y_pred == y_true))
print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=['no', 'yes']))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=['no', 'yes']).plot(cmap='Blues')
plt.show()
# Out:
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step
# ✅ Accuracy: 0.7323008849557522
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           no       0.73      0.73      0.73       226
#          yes       0.73      0.73      0.73       226
#
#     accuracy                           0.73       452
#    macro avg       0.73      0.73      0.73       452
# weighted avg       0.73      0.73      0.73       452

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf

RESULTS_DIR = "/content/efficientnetb0_results1"
os.makedirs(RESULTS_DIR, exist_ok=True)

checkpoint = ModelCheckpoint(os.path.join(RESULTS_DIR, "best_model.keras"),
                             monitor='val_accuracy', save_best_only=True, mode='max')
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=8,
    restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=40,
    callbacks=[checkpoint, earlystop, reduce_lr],
)
# Out:
# Epoch 1/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 429ms/step - accuracy: 0.6571 - loss: 0.5936 - val_accuracy: 0.7244 - val_loss: 0.5641 - learning_rate: 1.0000e-05
# Epoch 2/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 433ms/step - accuracy: 0.6895 - loss: 0.5794 - val_accuracy: 0.7600 - val_loss: 0.5513 - learning_rate: 1.0000e-05
# Epoch 3/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 430ms/step - accuracy: 0.6734 - loss: 0.5786 - val_accuracy: 0.7111 - val_loss: 0.5621 - learning_rate: 1.0000e-05
# Epoch 4/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 422ms/step - accuracy: 0.7050 - loss: 0.5607 - val_accuracy: 0.6644 - val_loss: 0.5790 - learning_rate: 1.0000e-05
# Epoch 5/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.6947 - loss: 0.5741
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 412ms/step - accuracy: 0.6948 - loss: 0.5740 - val_accuracy: 0.6289 - val_loss: 0.6225 - learning_rate: 1.0000e-05
# Epoch 6/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 432ms/step - accuracy: 0.7034 - loss: 0.5610 - val_accuracy: 0.7244 - val_loss: 0.5445 - learning_rate: 5.0000e-06
# Epoch 7/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 415ms/step - accuracy: 0.6736 - loss: 0.5721 - val_accuracy: 0.7156 - val_loss: 0.5364 - learning_rate: 5.0000e-06
# Epoch 8/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 408ms/step - accuracy: 0.7113 - loss: 0.5607 - val_accuracy: 0.7422 - val_loss: 0.5414 - learning_rate: 5.0000e-06
# Epoch 9/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 407ms/step - accuracy: 0.6771 - loss: 0.5809 - val_accuracy: 0.7133 - val_loss: 0.5351 - learning_rate: 5.0000e-06
# Epoch 10/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 416ms/step - accuracy: 0.7086 - loss: 0.5627 - val_accuracy: 0.7356 - val_loss: 0.5229 - learning_rate: 5.0000e-06

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.legend(); plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(); plt.title('Loss')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import numpy as np

model.load_weights(os.path.join(RESULTS_DIR, "best_model.keras"))

test_gen.reset()
preds = model.predict(test_gen, verbose=1)
y_pred = (preds > 0.5).astype(int).flatten()
y_true = test_gen.classes

print("✅ Accuracy:", np.mean(y_pred == y_true))
print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=['no', 'yes']))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=['no', 'yes']).plot(cmap='Blues')
plt.show()
# Out:
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
# ✅ Accuracy: 0.7522123893805309
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           no       0.74      0.77      0.76       226
#          yes       0.76      0.73      0.75       226
#
#     accuracy                           0.75       452
#    macro avg       0.75      0.75      0.75       452
# weighted avg       0.75      0.75      0.75       452

# %%
model.save(os.path.join(RESULTS_DIR, "final_model.keras"))
print("✅ Model and results saved to:", RESULTS_DIR)
# Out:
# ✅ Model and results saved to: /content/efficientnetb0_results1

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers, models, optimizers

def build_efficientnetb0(input_shape=(224,224,3)):
    base_model = EfficientNetB0(include_top=False, weights="imagenet", input_shape=input_shape)
    base_model.trainable = True

    inputs = layers.Input(shape=input_shape)
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs, outputs)
    model.compile(optimizer=optimizers.Adam(1e-5), loss='binary_crossentropy', metrics=['accuracy'])
    return model

model = build_efficientnetb0()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │         1,281 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,050,852 (15.45 MB)
#  Trainable params: 4,008,829 (15.29 MB)
#  Non-trainable params: 42,023 (164.16 KB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

RESULTS_DIR = "/content/efficientnetb0_result2"
os.makedirs(RESULTS_DIR, exist_ok=True)

checkpoint = ModelCheckpoint(os.path.join(RESULTS_DIR, "best_model.keras"),
                             monitor='val_accuracy', save_best_only=True, mode='max')
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=8,
    restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=40,
    callbacks=[checkpoint, earlystop, reduce_lr],
)
# Out:
# Epoch 1/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.5900 - loss: 0.6713 - val_accuracy: 0.5000 - val_loss: 0.7181 - learning_rate: 1.0000e-05
# Epoch 2/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 50s 431ms/step - accuracy: 0.7183 - loss: 0.5635 - val_accuracy: 0.5000 - val_loss: 0.7436 - learning_rate: 1.0000e-05
# Epoch 3/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 441ms/step - accuracy: 0.8156 - loss: 0.4856 - val_accuracy: 0.5000 - val_loss: 0.7484 - learning_rate: 1.0000e-05
# Epoch 4/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.8473 - loss: 0.4119
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 433ms/step - accuracy: 0.8473 - loss: 0.4118 - val_accuracy: 0.5000 - val_loss: 0.7520 - learning_rate: 1.0000e-05
# Epoch 5/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 451ms/step - accuracy: 0.8654 - loss: 0.3718 - val_accuracy: 0.5111 - val_loss: 0.7400 - learning_rate: 5.0000e-06
# Epoch 6/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 442ms/step - accuracy: 0.8957 - loss: 0.3354 - val_accuracy: 0.6378 - val_loss: 0.6484 - learning_rate: 5.0000e-06
# Epoch 7/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 448ms/step - accuracy: 0.9137 - loss: 0.3098 - val_accuracy: 0.7178 - val_loss: 0.5477 - learning_rate: 5.0000e-06
# Epoch 8/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 452ms/step - accuracy: 0.9049 - loss: 0.2947 - val_accuracy: 0.7311 - val_loss: 0.5502 - learning_rate: 5.0000e-06
# Epoch 9/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 40s 437ms/step - accuracy: 0.9247 - loss: 0.2586 - val_accuracy: 0.7267 - val_loss: 0.5376 - learning_rate: 5.0000e-06
# Epoch 10/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 431ms/step - accuracy: 0.9124 - loss: 0.2560 - val_accuracy: 0.6578 - val_loss: 0.5719 - learning_rate: 5.0000e-06
# Epoch 11/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 430ms/step - accuracy: 0.9341 - loss: 0.2295 - val_accuracy: 0.6844 - val_loss: 0.5183 - learning_rate: 5.0000e-06
# Epoch 12/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 446ms/step - accuracy: 0.9307 - loss: 0.2213 - val_accuracy: 0.8156 - val_loss: 0.4203 - learning_rate: 5.0000e-06
# Epoch 13/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 445ms/step - accuracy: 0.9460 - loss: 0.1958 - val_accuracy: 0.8222 - val_loss: 0.3897 - learning_rate: 5.0000e-06
# Epoch 14/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 446ms/step - accuracy: 0.9420 - loss: 0.1964 - val_accuracy: 0.9289 - val_loss: 0.2268 - learning_rate: 5.0000e-06
# Epoch 15/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 450ms/step - accuracy: 0.9514 - loss: 0.1702 - val_accuracy: 0.9444 - val_loss: 0.2030 - learning_rate: 5.0000e-06
# Epoch 16/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 431ms/step - accuracy: 0.9529 - loss: 0.1629 - val_accuracy: 0.7711 - val_loss: 0.4258 - learning_rate: 5.0000e-06
# Epoch 17/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 427ms/step - accuracy: 0.9549 - loss: 0.1490 - val_accuracy: 0.9178 - val_loss: 0.2287 - learning_rate: 5.0000e-06
# Epoch 18/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.9536 - loss: 0.1451
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 431ms/step - accuracy: 0.9536 - loss: 0.1451 - val_accuracy: 0.7778 - val_loss: 0.4011 - learning_rate: 5.0000e-06
# Epoch 19/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 432ms/step - accuracy: 0.9495 - loss: 0.1518 - val_accuracy: 0.8200 - val_loss: 0.3785 - learning_rate: 2.5000e-06
# Epoch 20/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 445ms/step - accuracy: 0.9459 - loss: 0.1589 - val_accuracy: 0.9511 - val_loss: 0.1740 - learning_rate: 2.5000e-06
# Epoch 21/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 435ms/step - accuracy: 0.9495 - loss: 0.1557 - val_accuracy: 0.8956 - val_loss: 0.2522 - learning_rate: 2.5000e-06
# Epoch 22/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 456ms/step - accuracy: 0.9653 - loss: 0.1208 - val_accuracy: 0.9667 - val_loss: 0.1432 - learning_rate: 2.5000e-06
# Epoch 23/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 445ms/step - accuracy: 0.9740 - loss: 0.1202 - val_accuracy: 0.9711 - val_loss: 0.1213 - learning_rate: 2.5000e-06
# Epoch 24/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 430ms/step - accuracy: 0.9625 - loss: 0.1256 - val_accuracy: 0.9689 - val_loss: 0.1234 - learning_rate: 2.5000e-06
# Epoch 25/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 430ms/step - accuracy: 0.9636 - loss: 0.1203 - val_accuracy: 0.9533 - val_loss: 0.1681 - learning_rate: 2.5000e-06
# Epoch 26/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9692 - loss: 0.1059
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 428ms/step - accuracy: 0.9692 - loss: 0.1059 - val_accuracy: 0.9111 - val_loss: 0.2314 - learning_rate: 2.5000e-06
# Epoch 27/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 427ms/step - accuracy: 0.9658 - loss: 0.1090 - val_accuracy: 0.9711 - val_loss: 0.1424 - learning_rate: 1.2500e-06
# Epoch 28/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 456ms/step - accuracy: 0.9583 - loss: 0.1239 - val_accuracy: 0.9822 - val_loss: 0.1050 - learning_rate: 1.2500e-06
# Epoch 29/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 441ms/step - accuracy: 0.9729 - loss: 0.1023 - val_accuracy: 0.9844 - val_loss: 0.0928 - learning_rate: 1.2500e-06
# Epoch 30/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 427ms/step - accuracy: 0.9737 - loss: 0.0976 - val_accuracy: 0.9800 - val_loss: 0.0950 - learning_rate: 1.2500e-06
# Epoch 31/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 444ms/step - accuracy: 0.9691 - loss: 0.1105 - val_accuracy: 0.9867 - val_loss: 0.0874 - learning_rate: 1.2500e-06
# Epoch 32/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 426ms/step - accuracy: 0.9653 - loss: 0.1060 - val_accuracy: 0.9867 - val_loss: 0.0777 - learning_rate: 1.2500e-06
# Epoch 33/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 448ms/step - accuracy: 0.9712 - loss: 0.0970 - val_accuracy: 0.9889 - val_loss: 0.0807 - learning_rate: 1.2500e-06
# Epoch 34/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 29s 435ms/step - accuracy: 0.9684 - loss: 0.1068 - val_accuracy: 0.9889 - val_loss: 0.0812 - learning_rate: 1.2500e-06
# Epoch 35/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.9744 - loss: 0.0906
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1e-06.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 431ms/step - accuracy: 0.9743 - loss: 0.0906 - val_accuracy: 0.9867 - val_loss: 0.0784 - learning_rate: 1.2500e-06
# Epoch 36/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 427ms/step - accuracy: 0.9732 - loss: 0.0926 - val_accuracy: 0.9889 - val_loss: 0.0783 - learning_rate: 1.0000e-06
# Epoch 37/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 423ms/step - accuracy: 0.9752 - loss: 0.0957 - val_accuracy: 0.9867 - val_loss: 0.0780 - learning_rate: 1.0000e-06
# Epoch 38/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 429ms/step - accuracy: 0.9725 - loss: 0.0909 - val_accuracy: 0.9867 - val_loss: 0.0786 - learning_rate: 1.0000e-06
# Epoch 39/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 423ms/step - accuracy: 0.9728 - loss: 0.0987 - val_accuracy: 0.9889 - val_loss: 0.0752 - learning_rate: 1.0000e-06
# Epoch 40/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 427ms/step - accuracy: 0.9740 - loss: 0.0914 - val_accuracy: 0.9800 - val_loss: 0.0921 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.legend(); plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(); plt.title('Loss')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import numpy as np

model.load_weights(os.path.join(RESULTS_DIR, "best_model.keras"))

test_gen.reset()
preds = model.predict(test_gen, verbose=1)
y_pred = (preds > 0.5).astype(int).flatten()
y_true = test_gen.classes

print("✅ Accuracy:", np.mean(y_pred == y_true))
print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=['no', 'yes']))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(cm, display_labels=['no', 'yes']).plot(cmap='Blues')
plt.show()
# Out:
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step
# ✅ Accuracy: 0.9756637168141593
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           no       0.98      0.97      0.98       226
#          yes       0.97      0.98      0.98       226
#
#     accuracy                           0.98       452
#    macro avg       0.98      0.98      0.98       452
# weighted avg       0.98      0.98      0.98       452
